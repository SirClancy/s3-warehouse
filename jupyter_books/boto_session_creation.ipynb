# %% [markdown]
# ### How to create Boto3 Session

# %%
#### Not required to execute if already installed
# !pip install awswrangler boto3 pandas configparser
# Out:
# Collecting awswrangler
#   Downloading awswrangler-3.9.1-py3-none-any.whl.metadata (17 kB)
# Collecting boto3
#   Downloading boto3-1.35.19-py3-none-any.whl.metadata (6.6 kB)
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting configparser
#   Downloading configparser-7.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting botocore<2.0.0,>=1.23.32 (from awswrangler)
#   Downloading botocore-1.35.19-py3-none-any.whl.metadata (5.7 kB)
# Collecting numpy<2.0,>=1.26 (from awswrangler)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 357.1 kB/s eta 0:00:001m459.7 kB/s eta 0:00:01
# Requirement already satisfied: packaging<25.0,>=21.1 in /home/sir/Documents/s3-warehouse/myenv/lib/python3.12/site-packages (from awswrangler) (24.1)
# Collecting pyarrow>=8.0.0 (from awswrangler)
#   Downloading pyarrow-17.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: setuptools in /home/sir/Documents/s3-warehouse/myenv/lib/python3.12/site-packages (from awswrangler) (75.0.0)
# Collecting typing-extensions<5.0.0,>=4.4.0 (from awswrangler)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sir/Documents/s3-warehouse/myenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sir/Documents/s3-warehouse/myenv/lib/python3.12/site-packages (from botocore<2.0.0,>=1.23.32->awswrangler) (2.2.3)
# Requirement already satisfied: six>=1.5 in /home/sir/Documents/s3-warehouse/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading awswrangler-3.9.1-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.7/381.7 kB 451.7 kB/s eta 0:00:001m460.6 kB/s eta 0:00:01
# Downloading boto3-1.35.19-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 509.9 kB/s eta 0:00:001m576.3 kB/s eta 0:00:01
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 913.7 kB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading configparser-7.1.0-py3-none-any.whl (17 kB)
# Downloading botocore-1.35.19-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 1.0 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pyarrow-17.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 1.7 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 2.2 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 1.4 MB/s eta 0:00:00m eta 0:00:01
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 2.0 MB/s eta 0:00:002.3 MB/s eta 0:00:01
# Installing collected packages: pytz, tzdata, typing-extensions, numpy, jmespath, configparser, pyarrow, pandas, botocore, s3transfer, boto3, awswrangler
# Successfully installed awswrangler-3.9.1 boto3-1.35.19 botocore-1.35.19 configparser-7.1.0 jmespath-1.0.1 numpy-1.26.4 pandas-2.2.2 pyarrow-17.0.0 pytz-2024.2 s3transfer-0.10.2 typing-extensions-4.12.2 tzdata-2024.1

# %%
#import below libraries
import awswrangler as wr
import pandas as pd
import boto3
import warnings 
warnings.filterwarnings('ignore')
import configparser

# %%
#reading the credentials securely.
credents = configparser.ConfigParser()

# %%
#use read_file method
credents.read_file(open('credentials.config'))

# %%
#Reading in the credentials into Python variables. No can see them
aws_key = credents["AWS"]["KEY"]
aws_secret = credents["AWS"]["SECRET"]
region = credents["AWS"]["REGION"]

# %%
boto3.Session()
# Out:
# Session(region_name=None)

# %%
#Creating the Session
your_session = boto3.Session(aws_access_key_id=aws_key,
                            aws_secret_access_key=aws_secret,
                            region_name=region)

# %% [markdown]
# ### Using the wr.s3.list_buckets() to verify your session

# %%
#verifying your session by listing the buckets
your_buckets = wr.s3.list_buckets(boto3_session=your_session)
your_buckets
# Out:
# ['aws-athena-query-results-us-east-1-872181313019',
#  'aws-glue-assets-872181313019-eu-north-1',
#  'spotifybucketday',
#  'weatherportlandcsv-yml']

# %% [markdown]
# ### If the above command throws error, then
#
# 1. Check if your Access credentials are active in AWS Console
# 2. Check you Internet Connection
# 3. Check your permissions in AWS console, if your account is provided by your company
